# %% [markdown]
# ## **For Loop**
#
# * When we know the exact number of iteration then we go for `for loop`.
# * Initilization and updation is not required in for loop.
# * It works on iterable data types.
# *
