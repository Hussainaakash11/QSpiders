# %%
# 1.Write a programme to find the square of given integer number.
a=int(input("Enter The Number:"))
print(a**2)
# Out:
# 36

# %%
# 2.Write a programme to find the substraction of two float values.
a=float(input("Enter The First Number:"))
b=float(input("Enter The Secomd Number:"))
print(a-b)
# Out:
# 2.9999999999999996

# %%
# 3.Write a programme to find the type of a given value.
a=eval(input("Enter The Number:"))
print(type(a))
# Out:
# <class 'float'>

# %%
# 4.Write a progrrame to find the length of a given input.
a=eval(input("Input Here:"))
b=len(a)
print(b)
# Out:
# 3

# %%
# 5.Write a programme to find the area of a rectangle.
l=eval(input("Enter The Length of rec:"))
b=eval(input("Enter The Breadth of rec:"))
print("Area of rec is:", l*b)
# Out:
# Area of rec is: 30

# %%
# 6.Write a programme to reverse a string .
s=eval(input("Enter The String"))
a=s[::-1]
print(a)
# Out:
# hsakaa

# %%
# 7.Write a programme to find the sum,product & division between two numbers.
a=eval(input("Enter first no:"))
b=eval(input("Enter second no:"))

print("Sum is:", a+b)
print("Product is:", a*b)
print("Div is:", a/b)
# Out:
# Sum is: 11
# Product is: 30
# Div is: 1.2
