# %% [markdown]
# # Python `if` and `if-else` Practice Questions
#
# This notebook contains solutions for all the given questions.
# Each program takes input from the user and displays the appropriate result.

# %% [markdown]
# ## Part A — `if` Statement

# %% [markdown]
# ### 1. Check whether a number is lying between 50 and 100

# %%
num = int(input("Enter a number: "))

if 50 <= num <= 100:
    print("The number lies between 50 and 100.")

# %% [markdown]
# ### 2. Check whether a string has more than 3 characters

# %%
text = input("Enter a string: ")

if len(text) > 3:
    print("The string has more than 3 characters.")

# %% [markdown]
# ### 3. Check whether a number has 4 digits

# %%
num = int(input("Enter a number: "))

if 1000 <= num <= 9999:
    print("The number has 4 digits.")
# Out:
# The number has 4 digits.

# %% [markdown]
# ### 4. Check whether a given character is a vowel

# %%
char = input("Enter a character: ")

if char in "aeiou":
    print("The character is a vowel.")
# Out:
# The character is a vowel.

# %% [markdown]
# ### 5. Check whether a given character is a consonant

# %%
char = input("Enter a character: ")

if len(char) == 1 and char.isalpha() and char.lower() not in "aeiou":
    print("The character is a consonant.")

# %% [markdown]
# ### 6. Check whether a number is a multiple of 5

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("The number is a multiple of 5.")

# %% [markdown]
# ### 7. Check whether a given character is an uppercase alphabet

# %%
char = input("Enter a character: ")

if 'A' <= char <= 'Z':
    print("The character is an uppercase alphabet.")
# Out:
# The character is an uppercase alphabet.

# %% [markdown]
# ### 12. Check whether a number is even

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is even.")

# %% [markdown]
# ### 13. Check whether the person is an adult

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are an adult.")

# %% [markdown]
# ### 14. Check whether the temperature is cold

# %%
temperature = float(input("Enter the temperature: "))

if temperature < 15:
    print("It's cold.")

# %% [markdown]
# ### 15. Check whether a string is equal to 'hello'

# %%
text = input("Enter a string: ")

if text == "hello":
    print("Greeting detected!")

# %% [markdown]
# ## Part B — `if-else` Statement

# %% [markdown]
# ### 1. Check if a number is even or odd

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")

# %% [markdown]
# ### 2. Check if a person is eligible to vote

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")

# %% [markdown]
# ### 3. Check if a number is positive or not

# %%
num = eval(input("Enter a number: "))

if num > 0:
    print("The number is positive.")
else:
    print("The number is not positive.")

# %% [markdown]
# ### 4. Check if two numbers are equal or not

# %%
num1 = eval(input("Enter the first number: "))
num2 = eval(input("Enter the second number: "))

if num1 == num2:
    print("Both numbers are equal.")
else:
    print("The numbers are not equal.")

# %% [markdown]
# ### 5. Check if a number is divisible by 5

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("The number is divisible by 5.")
else:
    print("The number is not divisible by 5.")

# %% [markdown]
# ### 6. Check if a character is a vowel or consonant

# %%
char = input("Enter a character: ")

if len(char) == 1 and char.isalpha():
    if char.lower() in "aeiou":
        print("The character is a vowel.")
    else:
        print("The character is a consonant.")
else:
    print("Please enter a single alphabet.")
# Out:
# The character is a vowel.

# %%
char = input("Enter a character: ")

if char in 'aeiou' or char in 'AEIOU':
    print("Char is vowel")
else:
    print("Char is consonant")
# Out:
# Char is vovel

# %% [markdown]
# ### 7. Check if a number is within the range 1–100

# %%
num = int(input("Enter a number: "))

if 1 <= num <= 100:
    print("The number is within the range 1–100.")
else:
    print("The number is outside the range 1–100.")
# Out:
# The number is within the range 1–100.

# %% [markdown]
# ### 8. Check if a string is empty or not

# %%
text = input("Enter a string: ")

if text == "":
    print("The string is empty.")
else:
    print("The string is not empty.")

# %% [markdown]
# ### 9. Check if a number is a multiple of 3

# %%
num = int(input("Enter a number: "))

if num % 3 == 0:
    print("The number is a multiple of 3.")
else:
    print("The number is not a multiple of 3.")

# %% [markdown]
# ### 10. Check if a password is correct

# %%
password = input("Enter the password: ")

if password == "python123":
    print("Password is correct.")
else:
    print("Password is incorrect.")
# Out:
# Password is correct.

# %% [markdown]
# ### 11. Check if a number is greater than 100

# %%
num = float(input("Enter a number: "))

if num > 100:
    print("The number is greater than 100.")
else:
    print("The number is not greater than 100.")

# %% [markdown]
# ### 12. Check if a number is negative

# %%
num = float(input("Enter a number: "))

if num < 0:
    print("The number is negative.")
else:
    print("The number is not negative.")

# %% [markdown]
# ### 13. Check if a number is a two-digit number

# %%
num = int(input("Enter a number: "))

if 10 <= abs(num) <= 99:
    print("The number is a two-digit number.")
else:
    print("The number is not a two-digit number.")
# Out:
# The number is a two-digit number.

# %%
num = eval(input("Enter a number: "))
n = abs(num)
new=str(n)
if len(new)==2:
    print("The number is a two-digit number.")
else:
    print("The number is not a two-digit number.")
# Out:
# The number is a two-digit number.

# %% [markdown]
# ### 14. Check if a person is tall (height > 170 cm)

# %%
height = float(input("Enter height in cm: "))

if height > 170:
    print("The person is tall.")
else:
    print("The person is not tall.")

# %% [markdown]
# ### 15. Check if one number is the square of another

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

if num1 == num2 ** 2 or num2 == num1 ** 2:
    print("One number is the square of the other.")
else:
    print("Neither number is the square of the other.")
# Out:
# One number is the square of the other.

# %% [markdown]
# ### 16. Check if the temperature is above the freezing point

# %%
temperature = float(input("Enter the temperature in Celsius: "))

if temperature > 0:
    print("The temperature is above the freezing point.")
else:
    print("The temperature is at or below the freezing point.")

# %% [markdown]
# ### 17. Check if a year is before or after 2000

# %%
year = int(input("Enter a year: "))

if year < 2000:
    print("The year is before 2000.")
else:
    print("The year is 2000 or after 2000.")

# %% [markdown]
# ### 18. Check if a student passed (marks ≥ 40)

# %%
marks = float(input("Enter marks: "))

if marks >= 40:
    print("The student passed.")
else:
    print("The student failed.")

# %% [markdown]
# ### 19. Check if a number is less than 10 or not

# %%
num = float(input("Enter a number: "))

if num < 10:
    print("The number is less than 10.")
else:
    print("The number is not less than 10.")

# %% [markdown]
# ### 20. Check if an entered letter is uppercase or not

# %%
letter = input("Enter a letter: ")

if 'A' <= letter <= 'Z':
    print("The letter is uppercase.")
else:
    print("The letter is not uppercase.")
# Out:
# The letter is not uppercase.

# %% [markdown]
# ### 21. Check whether a year is a leap year or not

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("The year is a leap year.")
else:
    print("The year is not a leap year.")
