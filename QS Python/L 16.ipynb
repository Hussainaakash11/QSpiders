# %% [markdown]
# ## **Membership Operator**
#
# * It's used to check the given value is present inside the collection or not.
# * It returns boolean output

# %%
d1= {'a':10, 'b':20}
10 in d1
# Out:
# False
